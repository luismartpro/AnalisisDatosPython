# %%
pip install "pymongo[srv]"

# %%
pip install sqlalchemy

# %%
pip install mysqlclient

# %%
import sqlalchemy as db # librearias para trabajar
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db") # nosconetamos a la base de datos 
conn = engine.connect()

# %%
customers_df = pd.read_sql_query('select * from customers', con=conn) # leemos la base de datos y traemos la tabla customers
customers_df

# %%
customers_df_2 = pd.read_sql_table('categories', engine) # leer una tabla de la base de datos de otra forma 
customers_df_2

# %%
from pymongo import MongoClient # nos conectamso a la base de datos de mongodb
conn_string = "mongodb+srv://luimarper045:MI4bT76eB6lOOlIs@cluster0.hjxcd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(conn_string)

client['bd_test']
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.hjxcd.mongodb.net:27017', 'cluster0-shard-00-00.hjxcd.mongodb.net:27017', 'cluster0-shard-00-02.hjxcd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-1zltow-shard-0', tls=True), 'bd_test')

# %%
coleccion = client['bd_test']['tabla']
df = coleccion.find({})
df

# %%
coleccion = client['sample_mflix']['embedded_movies'] # colocamos base de datos y tabla de mongo db
cursor_mongo = coleccion.find({})

df = pd.DataFrame(cursor_mongo)
df
# Out:
#                            _id  \
# 0     573a1391f29313caabcd93a3
# 1     573a1391f29313caabcd8319
# 2     573a1392f29313caabcd9ca6
# 3     573a1392f29313caabcdac22
# 4     573a1390f29313caabcd5293
# ...                        ...
# 3478  573a13f3f29313caabddfde0
# 3479  573a13e2f29313caabdbf161
# 3480  573a13edf29313caabdd3a09
# 3481  573a13eef29313caabdd6ff4
# 3482  573a13f7f29313caabde65b4
#
#                                                    plot  \
# 0     Navy divers clear the torpedo tube of a sunken...
# 1     An irresponsible young millionaire changes his...
# 2     An ambitious and near insanely violent gangste...
# 3     A major countermands orders and attacks to rev...
# 4     Young Pauline is left a lot of money when her ...
# ...                                                 ...
# 3478  Two siblings discover a supernatural escape fr...
# 3479  Inspector Richard Kemp never got around to put...
# 3480  A 74-year-old widow realizes she is becoming a...
# ...
